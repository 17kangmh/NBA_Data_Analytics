# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

data = pd.read_excel('nba_player_data.xlsx')
data
# Out:
#          Year Season_type  PLAYER_ID  RANK           PLAYER     TEAM_ID TEAM  \
# 0     2012-13     Regular       2546     1  Carmelo Anthony  1610612752  NYK
# 1     2012-13     Regular     201142     2     Kevin Durant  1610612760  OKC
# 2     2012-13     Regular        977     3      Kobe Bryant  1610612747  LAL
# 3     2012-13     Regular       2544     4     LeBron James  1610612748  MIA
# 4     2012-13     Regular     201935     5     James Harden  1610612745  HOU
# ...       ...         ...        ...   ...              ...         ...  ...
# 4387  2023-24    Playoffs     203143   179   Pablo Prigioni  1610612752  NYK
# 4388  2023-24    Playoffs       2563   180    Dahntay Jones  1610612737  ATL
# 4389  2023-24    Playoffs     203110   181   Draymond Green  1610612744  GSW
# 4390  2023-24    Playoffs     101236   182      Chuck Hayes  1610612758  SAC
# 4391  2023-24    Playoffs     203105   183     Festus Ezeli  1610612744  GSW
#
# ...

# %%
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 data
#
# NameError: name 'data' is not defined
